# %%
import face_recognition
import cv2
print(cv2.getBuildInformation())
# Out:
# General configuration for OpenCV 4.5.3 =====================================
#   Version control:               20bea4d-dirty
#
#   Extra modules:
#     Location (extra):            /home/conda/feedstock_root/build_artifacts/libopencv_1633800893877/work/opencv_contrib/modules
#     Version control (extra):     20bea4d-dirty
#
#   Platform:
#     Timestamp:                   2021-10-09T17:44:39Z
#     Host:                        Linux 5.8.0-1042-azure x86_64
#     CMake:                       3.21.3
#     CMake generator:             Ninja
#     CMake build tool:            /home/conda/feedstock_root/build_artifacts/libopencv_1633800893877/_build_env/bin/ninja
#     Configuration:               Release
#
#   CPU/HW features:
#     Baseline:                    SSE SSE2 SSE3
#       requested:                 SSE3
#     Dispatched code generation:  SSE4_1 SSE4_2 FP16 AVX AVX2 AVX512_SKX
#       requested:                 SSE4_1 SSE4_2 AVX FP16 AVX2 AVX512_SKX
# ...
